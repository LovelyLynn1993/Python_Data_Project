# %%
job_count= 42

# %%
print(job_count)
# Out:
# 42

# %%
job_title= 'Data Engineer'

# %%
company_name= 'DataWorks'

# %%
remote= True

# %%
print(job_title,company_name,remote)
# Out:
# Data Engineer DataWorks True

# %%
base_salary= 120000

# %%
bonus= 20000

# %%
total_compensation= base_salary + bonus

# %%
print(total_compensation)
# Out:
# 140000

# %%
annual_salary = 72000

# %%
monthly_salary = annual_salary/12

# %%
print(monthly_salary)
# Out:
# 6000.0

# %%
job_title = 'Data Scientist'

# %%
company_name = 'AI Solutions'

# %%
salary = 110000

# %%
bonus = .10

# %%
total_compensation = (salary) * (1 + bonus)

# %%
print(total_compensation)
# Out:
# 121000.00000000001

# %%
print(job_title,company_name,total_compensation)
# Out:
# Data Scientist AI Solutions 121000.00000000001

# %%
job_title = 'Data Scientist'

# %%
type(job_title)
# Out:
# str

# %%
print(type(job_title))
# Out:
# <class 'str'>

# %%
salary = 85000.50

# %%
print(type(salary))
# Out:
# <class 'float'>

# %%
salary_rate = 120000.75

# %%
salary_rate = int(salary_rate)

# %%
print(type(salary_rate))
# Out:
# <class 'int'>

# %%
company_name = 'DataWiz Inc.'

# %%
type(company_name)
# Out:
# str

# %%
isinstance(company_name,str)
# Out:
# True

# %%
print(isinstance(company_name,str))
# Out:
# True

# %%
job_title = 'data scientist'

# %%
job_title.upper()
# Out:
# 'DATA SCIENTIST'

# %%
print(job_title.upper())
# Out:
# DATA SCIENTIST

# %%
job_title = 'Data Analyst'

# %%
new_job_title = job_title.replace('Analyst','Engineer')

# %%
print(new_job_title)
# Out:
# Data Engineer

# %%
seniority_level = 'Senior'

# %%
job_title = 'Data Analyst'

# %%
full_job_title = seniority_level + ' ' + job_title

# %%
print(full_job_title)
# Out:
# Senior Data Analyst

# %%
job_title = 'Data Scientist'

# %%
len (job_title)
# Out:
# 14

# %%
job_title_length = len(job_title)

# %%
print(job_title_length)
# Out:
# 14

# %%
job_title = 'DATA ENGINEER'

# %%
job_title = 'Data Scientist'

# %%
job_title_new = f'Job Title: {job_title}'

# %%
print(job_title_new)
# Out:
# Job Title: Data Scientist

# %%
result = 'Job Title: ' + job_title

# %%
print(result)
# Out:
# Job Title: Data Scientist

# %%
position = 'Data Scientist'
company = 'DataWiz Inc.'

# %%
format_string = f'{position} at {company}'

# %%
print(format_string)
# Out:
# Data Scientist at DataWiz Inc.

# %%
role = 'Data Analyst'

# %%
skill = 'Python'

# %%
string_format = f'Role: {role}, Skill: {skill}'

# %%
print(string_format)
# Out:
# Role: Data Analyst, Skill: Python

# %%
role = 'Data Engineer'

# %%
skill = 'SQL'

# %%
result = f'Role: %s, Skill: %s' % (role, skill)

# %%
print(result)
# Out:
# Role: Data Engineer, Skill: SQL

# %%
monthly_salary = 8000

# %%
annual_salary = monthly_salary * 12

# %%
print(annual_salary)
# Out:
# 96000

# %%
avg_salary_analyst = 70000
avg_salary_scientist = 85000

# %%
greater_salary = avg_salary_analyst > avg_salary_scientist

# %%
print(greater_salary)
# Out:
# False

# %%
total_applications = 123
job_openings = 67

# %%
results = total_applications % job_openings

# %%
print(results)
# Out:
# 56

# %%
job_postings = 20

# %%
job_postings += 5
print(job_postings)
# Out:
# 25

# %%
min_salary = 50000
max_salary = 120000

# %%
avg_salary = (min_salary + max_salary) / 2

# %%
print(avg_salary)
# Out:
# 85000.0

# %%
python_expirence = 3
if python_expirence < 2:
  print('Beginner')
else:
  print('Intermediate')
# Out:
# Intermediate

# %%
if python_expirence < 2:
  skill_level = 'Beginner'
else:
  skill_level = 'Intermediate'
print(skill_level)
# Out:
# Intermediate

# %%
tools_known = 3
if tools_known <= 1:
  skill_level = 'Beginner'
elif tools_known <= 4:
  skill_level = 'Intermediate'
else:
  skill_level = 'Advanced'
print(skill_level)
# Out:
# Intermediate

# %%
job_expirence = 4
sql_expirence = 2
if job_expirence < 2 and sql_expirence == 0:
  results = 'Associate Analyst'
elif job_expirence < 2 and sql_expirence >= 1:
  results = 'Junior Analyst'
elif job_expirence < 5 and sql_expirence == 0:
  results = 'Associate Analyst'
elif job_expirence < 5 and sql_expirence == 1:
  results = 'Intermediate Analyst'
elif job_expirence < 5 and sql_expirence >= 2:
  results = 'Senior Analyst'
elif job_expirence > 5 and sql_expirence <= 2:
  results = 'Data Analyst'
elif job_expirence > 5 and sql_expirence >= 3:
  results = 'Lead Analyst'
print(results)
# Out:
# Senior Analyst

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

# %%
print(job_titles[1])
# Out:
# Data Analyst

# %%
job_titles.append('Machine learning Engineer')

# %%
job_titles
# Out:
# ['Data Scientist',
#  'Data Analyst',
#  'Machine Learning Engineer',
#  'Machine learning Engineer']

# %%
job_titles.remove('Machine Learning Engineer')

# %%
job_titles
# Out:
# ['Data Scientist', 'Data Analyst', 'Machine learning Engineer']

# %%
print (job_titles)
# Out:
# ['Data Scientist', 'Data Analyst', 'Machine learning Engineer']

# %%
job_titles.remove('Machine learning Engineer')

# %%
job_titles
# Out:
# ['Data Scientist', 'Data Analyst']

# %%
job_titles.append('AI Specialist')
print(job_titles)
# Out:
# ['Data Scientist', 'Data Analyst', 'AI Specialist']

# %%
job_titles[2] = 'Machine Learning Engineer'
print(job_titles)
# Out:
# ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

# %%
job_titles.append('Data Engineer')
print(job_titles)
# Out:
# ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Engineer']

# %%
job_titles[0:2]
# Out:
# ['Data Scientist', 'Data Analyst']

# %%
print(job_titles)
# Out:
# ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Engineer']

# %%
job_titles.remove('Data Engineer')

# %%
job_titles.insert(1,'Business Analyst')
print(job_titles)
# Out:
# ['Data Scientist', 'Business Analyst', 'Data Analyst', 'Machine Learning Engineer']

# %%
job_titles
# Out:
# ['Data Scientist',
#  'Business Analyst',
#  'Data Analyst',
#  'Machine Learning Engineer']

# %%
job_titles.remove('Business Analyst')

# %%
print(job_titles)
# Out:
# ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

# %%
job_postings = {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}

# %%
print(job_postings['Data Analyst'])
# Out:
# 80

# %%
job_postings['AI Specialist'] = 30
print(job_postings)
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50, 'AI Specialist': 30}

# %%
job_postings.pop('AI Specialist')
print(job_postings)
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50}

# %%
job_postings.pop('Machine Learning Engineer')
print(job_postings)
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80}

# %%
job_postings1 = {'Data Scientist': 120, 'Data Analyst': 80}
job_postings2 = {'Machine Learning Engineer': 50, 'AI Specialist': 30}

# %%
job_postings1.update(job_postings2)
print(job_postings1)
# Out:
# {'Data Scientist': 120, 'Data Analyst': 80, 'Machine Learning Engineer': 50, 'AI Specialist': 30}

# %%
job_details = {
'Data Scientist': {'openings': 120, 'salary': 120000},
'Data Analyst': {'openings': 80, 'salary': 80000},
'Machine Learning Engineer': {'openings': 50, 'salary': 110000}
}
print(job_details)
# Out:
# {'Data Scientist': {'openings': 120, 'salary': 120000}, 'Data Analyst': {'openings': 80, 'salary': 80000}, 'Machine Learning Engineer': {'openings': 50, 'salary': 110000}}

# %%
unique_job_titles = {'Data Scientist', 'Data Analyst', 'Machine Learnign Engineer'}

# %%
unique_job_titles.add('AI Specialist')
print(unique_job_titles)
# Out:
# {'AI Specialist', 'Machine Learnign Engineer', 'Data Analyst', 'Data Scientist'}

# %%
unique_job_titles = {'Data Scientist', 'Data Analyst', 'Machine Learning Engineer'}
unique_job_titles.remove('Data Analyst')
print(unique_job_titles)
# Out:
# {'Machine Learning Engineer', 'Data Scientist'}

# %%
job_locations = ['New York', 'San Francisco', 'New York', 'Austin', 'San Francisco']
print(set(job_locations))
# Out:
# {'Austin', 'San Francisco', 'New York'}

# %%
skills_set1 = {'Python', 'SQL', 'Tableau'}
skills_set2 = {'R', 'SQL', 'Machine Learning'}
print(skills_set1.union(skills_set2))
# Out:
# {'Machine Learning', 'R', 'SQL', 'Tableau', 'Python'}

# %%
job_roles = ('Data Scientist', 'Data Analyst', 'machine Learning Engineer')

# %%
print(job_roles[1])
# Out:
# Data Analyst

# %%
extended_job_roles = job_roles + ('AI Specialist',)
print(extended_job_roles)
# Out:
# ('Data Scientist', 'Data Analyst', 'machine Learning Engineer', 'AI Specialist')

# %%
job_roles = ('Data Scientist', 'Data Analyst', 'Machine Learning Engineer')

# %%
job_roles = list(job_roles)
print(job_roles)
# Out:
# ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

# %%
job_roles.remove('Data Analyst')
job_roles = tuple(job_roles)
print(job_roles)
# Out:
# ('Data Scientist', 'Machine Learning Engineer')

# %%
job_postings = (120, 80, 50)

# %%
data_scientist_postings, data_analyst_postings, ml_enigineer_postings = job_postings
print(data_scientist_postings)
print(data_analyst_postings)
print(ml_enigineer_postings)
# Out:
# 120
# 80
# 50

# %%
job_details = (('Data Scientist', 120), ('Data Analyst', 80), ('Machine learning Engineer', 50))

# %%
job_details = list(job_details)

# %%
print(job_details[2][1])
# Out:
# 50

# %%
job_title1 = 'Data Engineer'
job_title2 = 'Data Scientist'

# %%
print(job_title1 is not job_title2)
# Out:
# True

# %%
job_locations = ['New York', 'San Francisco', 'Austin']
print('New York' in job_locations)
# Out:
# True

# %%
job_title = 'Data Analyst'
job_description = 'Data Scientist at Tech Corp'
print(job_title not in job_description)
# Out:
# True

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
print('Data Scientist' and 'Machine Learning Engineer' in job_titles)
# Out:
# True

# %%
salary1 = 100000
salary2 = 50000
print((salary1) | (salary2))
# Out:
# 116720

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']
for title in job_titles:
  print(title)
# Out:
# Data Scientist
# Data Analyst
# Machine Learning Engineer

# %%
job_postings = [5, 10, 15, 20, 25]

# %%
total_postings = 0
index = 0
while index < len(job_postings):
  total_postings += job_postings[index]
  index += 1
print(total_postings)
# Out:
# 75

# %%
job_titles = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer']

# %%
help(enumerate)
# Out:
# Help on class enumerate in module builtins:
#
# class enumerate(object)
#  |  enumerate(iterable, start=0)
#  |
#  |  Return an enumerate object.
#  |
#  |    iterable
#  |      an object supporting iteration
#  |
#  |  The enumerate object yields pairs containing a count (from start, which
#  |  defaults to zero) and a value yielded by the iterable argument.
#  |
#  |  enumerate is useful for obtaining an indexed list:
#  |      (0, seq[0]), (1, seq[1]), (2, seq[2]), ...
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  __class_getitem__(...)
#  |      See PEP 585
#  |
# ...

# %%
for index, title in enumerate(job_titles):
  print(f'{index}: {title}')
# Out:
# 0: Data Scientist
# 1: Data Analyst
# 2: Machine Learning Engineer

# %%
job_title = ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Software Engineer']
index = 0
while index < len(job_titles):
  if 'Engineer' in job_titles[index]:
    print(job_titles[index])
    break
  index += 1
# Out:
# Machine Learning Engineer

# %%
position_skills = {'Data Scientist': ['Python', 'R'],
                   'Data Analyst': ['SQL', 'Excel'],
                   'Machine Learning Engineer': ['Python', 'TensorFlow']}

# %%
for position, skills in position_skills.items():
  for skill in skills:
    print(f'The role of {position}, requires profeiciency in {skill}.')
# Out:
# The role of Data Scientist, requires profeiciency in Python.
# The role of Data Scientist, requires profeiciency in R.
# The role of Data Analyst, requires profeiciency in SQL.
# The role of Data Analyst, requires profeiciency in Excel.
# The role of Machine Learning Engineer, requires profeiciency in Python.
# The role of Machine Learning Engineer, requires profeiciency in TensorFlow.

# %%
salaries_usd = [100000, 120000, 80000, 90000]

# %%
salary_eur = [x*0.85 for x in salaries_usd]
print(salary_eur)
# Out:
# [85000.0, 102000.0, 68000.0, 76500.0]

# %%
job_expirence = {'Data Scientist': 3, 'Data Analyst': 1, 'Machine Learning Specialist': 4, 'Data Engineer': 2}
job_titles = [titles for titles in job_expirence if job_expirence[titles] > 2]
print(job_titles)
# Out:
# ['Data Scientist', 'Machine Learning Specialist']

# %%
job_salary_dicts = [
    {'job_title': 'Data Scientist', 'salary': 100000},
    {'job_title': 'Data Analyst', 'salary': 120000},
    {'job_title': 'Data Engineer', 'salary': 80000},
    {'job_title': 'Machine Learning Enigineer', 'salary': 90000}
]

# %%
job_salary = [job['job_title'] for job in job_salary_dicts if job['salary'] > 90000]
print(job_salary)
# Out:
# ['Data Scientist', 'Data Analyst']

# %%
job_title = 'Data Scientist'
keyword = 'Data'

# %%
def job_title_contains(job_title, keyword):
  return keyword in job_title
print (job_title_contains(job_title, keyword))
# Out:
# True

# %%
salaries = [95000, 120000, 105000, 90000, 130000]

# %%
def avaerage_salary(salaries):
  return sum(salaries) / len(salaries)
print(avaerage_salary(salaries))
# Out:
# 108000.0

# %%
list(salaries)
# Out:
# [95000, 120000, 105000, 90000, 130000]

# %%
def salary_statistics(salaries):
  return {
      'min': min(salaries),
      'max': max(salaries),
      'average': sum(salaries) / len(salaries)
  }
print(salary_statistics(salaries))
# Out:
# {'min': 90000, 'max': 130000, 'average': 108000.0}

# %%
job_postings = [
    {'title': 'Data Scientist', 'location': 'New York', 'salary': 95000},
    {'title': 'Data Analyst', 'location': 'San Francisco', 'salary': 85000},
    {'title': 'Machine Learning Engineer', 'location': 'New York', 'salary': 115000}
]

# %%
def job_posting_summary(job_postings):
  return {
          'total postings': len(job_postings),
          'average salary': sum(job['salary'] for job in job_postings) / len(job_postings),
          'unique_locations': list(set(job['location'] for job in job_postings))
          }

# %%
job_posting_summary(job_postings)
# Out:
# {'total postings': 3,
#  'average salary': 98333.33333333333,
#  'unique_locations': ['San Francisco', 'New York']}

# %%
salaries = [95000, 120000, 105000, 90000, 130000]

# %%
average_salary = lambda salaries: sum(salaries) / len(salaries)
average = average_salary(salaries)
print(average)
# Out:
# 108000.0

# %%
job_titles = ['Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'Data Analyst']
list(filter(lambda title: 'Data' in title, job_titles))
# Out:
# ['Data Scientist', 'Data Engineer', 'Data Analyst']

# %%
job_postings = [
    {'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
    {'title': 'Data Analyst', 'skills': ['Excel', 'SQL'], 'remote': False},
    {'title': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow'], 'remote': True},
    {'title': 'Software Developer', 'skills': ['Java', 'C++'], 'remote': True}
]

# %%
filter_list = lambda job: 'Python' in job['skills'] and job['remote']

# %%
skill_remote_jobs = list(filter(filter_list, job_postings))
skill_remote_jobs
# Out:
# [{'title': 'Data Scientist', 'skills': ['Python', 'SQL'], 'remote': True},
#  {'title': 'Machine Learning Engineer',
#   'skills': ['Python', 'TensorFlow'],
#   'remote': True}]

# %%
class JobPosting:
  def __init__(self, title, company, location):
    self.title = title
    self.company = company
    self.location = location

# %%
job = JobPosting('Data Scientist', 'Tech Innovations', 'New York')
print(job.title)
print(job.company)
print(job.location)
# Out:
# Data Scientist
# Tech Innovations
# New York

# %%
class JobPosting:
  def __init__(self, title, company, location, salary):
    self.title = title
    self.company = company
    self.location = location
    self.salary = salary
  def to_dict(self):
    return {
        'title': self.title,
        'company': self.company,
        'location': self.location,
        'salary': self.salary
    }

# %%
job = JobPosting('Data Scientist', 'Tech Innovations', 'New York', 120000)
print(job.to_dict())
# Out:
# {'title': 'Data Scientist', 'company': 'Tech Innovations', 'location': 'New York', 'salary': 120000}

# %%
class JobPosting:
  def __init__(self, title, company, location, salary):
    self.title = title
    self.company = company
    self.location = location
    self.salary = salary
  def compare_salary(self, other_job):
    if self.salary > other_job.salary:
      return self.title
    else:
      return other_job.title

# %%
job1 = JobPosting('Data Scientist', 'Tech Innovations', 'New York', 120000)
job2 = JobPosting('Data Analyst', 'Data Driven Co', 'San Fransico', 100000)
print(job1.compare_salary(job2))
# Out:
# Data Scientist

# %%
import numpy as np

# %%
applications_list = np.array([10, 15, 7, 20, 25, 30, 5])
applications = applications_list
print(applications)
# Out:
# [10 15  7 20 25 30  5]

# %%
postings_list = np.array([10, 15, 7, 20, 25, 30, 5])
postings = postings_list
first_three_jobs = postings[:3]
print(first_three_jobs)
# Out:
# [10 15  7]

# %%
salaries = np.array([70000, 85000, 60000, 95000, 80000])
max_salary = np.max(salaries)
min_salary = np.min(salaries)
print(max_salary, min_salary)
# Out:
# 95000 60000

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df['total_bedrooms']
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %%
df['total_bedrooms'][2999]
# Out:
# np.float64(263.0)

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/785741 [00:00<?, ? examples/s]

# %%
df = dataset['train'].to_pandas()

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.tail(5)
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %%
df['job_location']
# Out:
# 0                               Watertown, CT
# 1                Guadalajara, Jalisco, Mexico
# 2                             Berlin, Germany
# 3                             San Antonio, TX
# 4                              Washington, DC
#                          ...
# 785736                              Singapura
# 785737                     Bad Rodach, Jerman
# 785738                               Malaysia
# 785739    Newark, New Jersey, Amerika Serikat
# 785740                                  India
# Name: job_location, Length: 785741, dtype: object

# %%
df.search_location
# Out:
# 0         Texas, United States
# 1                       Mexico
# 2                      Germany
# 3         Texas, United States
# 4                        Sudan
#                   ...
# 785736               Singapore
# 785737                 Germany
# 785738                Malaysia
# 785739                   Sudan
# 785740                   India
# Name: search_location, Length: 785741, dtype: object

# %%
df.job_title[56]
# Out:
# 'Principal Statistical Scientist'

# %%
df.iloc[2]
# Out:
# job_title_short                                              Data Engineer
# job_title                Data Engineer/Scientist/Analyst, Mid or Senior...
# job_location                                               Berlin, Germany
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Germany
# job_posted_date                                        2023-10-10 13:14:55
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Germany
# salary_rate                                                           None
# ...

# %%
df.job_country.unique()
# Out:
# array(['United States', 'Mexico', 'Germany', 'Sudan', 'Romania',
#        'Denmark', 'Switzerland', 'France', 'Brazil', 'United Kingdom',
#        'India', 'Poland', 'Belgium', 'Russia', 'Serbia', 'Singapore',
#        'Costa Rica', 'Ireland', 'Italy', 'Malaysia', 'Canada', 'Uruguay',
#        'Namibia', 'Estonia', 'Israel', 'Hungary', 'Austria',
#        'Philippines', 'Egypt', 'Australia', 'Chile', 'Spain',
#        'Netherlands', 'South Africa', 'Colombia', 'Hong Kong', 'Kuwait',
#        'Finland', 'Luxembourg', 'China', 'Puerto Rico', 'Sweden',
#        'Saudi Arabia', 'Argentina', 'Turkey', 'Panama', 'Nigeria',
#        'New Zealand', 'Ukraine', 'Jordan', 'United Arab Emirates',
#        'Armenia', 'Pakistan', 'Lesotho', 'Mauritius', 'Portugal',
#        'Bahrain', 'Taiwan', "Côte d'Ivoire", 'U.S. Virgin Islands',
#        'Réunion', 'Kazakhstan', 'Lithuania', 'Moldova', 'Belarus',
#        'Cyprus', 'Bulgaria', 'Honduras', 'Czechia', 'Peru', 'South Korea',
# ...

# %%
filtered_df = df[df.job_schedule_type == 'Full-time']

# %%
filtered_df.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# 0               False  Texas, United States  2023-06-16 13:44:15
# 1               False                Mexico  2023-01-14 13:18:07
# 2               False               Germany  2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# ...

# %%
df.job_skills.notna()
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 785736     True
# 785737     True
# 785738     True
# 785739     True
# 785740     True
# Name: job_skills, Length: 785741, dtype: bool

# %%
filtered = df[df.job_skills.notna()]

# %%
filtered.head()
# Out:
#   job_title_short                                          job_title  \
# 1    Data Analyst                                       Data Analyst
# 2   Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3   Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4   Data Engineer                             Data Engineer- Sr Jobs
# 5   Data Engineer                                  GCP Data Engineer
#
#                    job_location             job_via         job_schedule_type  \
# 1  Guadalajara, Jalisco, Mexico    via BeBee México                 Full-time
# 2               Berlin, Germany        via LinkedIn                 Full-time
# 3               San Antonio, TX   via Diversity.com                 Full-time
# 4                Washington, DC  via Clearance Jobs                 Full-time
# 5                      Anywhere    via ZipRecruiter  Contractor and Temp work
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
sorted_df = df.sort_values(by= 'salary_year_avg', ascending=False)

# %%
sorted_df.head(10)
# Out:
#               job_title_short  \
# 554784         Data Scientist
# 665811  Senior Data Scientist
# 168402           Data Analyst
# 387378         Data Scientist
# 160521         Data Scientist
# 404932          Data Engineer
# 554140         Data Scientist
# 417241  Senior Data Scientist
# 618461  Senior Data Scientist
# 124265         Data Scientist
#
#                                                 job_title  \
# 554784                                     Data Scientist
# 665811                              Senior Data Scientist
# 168402                                       Data Analyst
# 387378  Geographic Information Systems Analyst - GIS A...
# 160521              Staff Data Scientist/Quant Researcher
# 404932               Hybrid - Data Engineer - Up to $600k
# 554140          Staff Data Scientist - Business Analytics
# 417241                              Senior Data Scientist
# 618461                         VP Data Science & Research
# ...

# %%
df['is_remote'] = df.job_work_from_home

# %%
df['is_remote']
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: is_remote, Length: 785741, dtype: bool

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_posted_year'] = df['job_posted_date'].dt.year

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
mean_salary = df[['salary_year_avg']].mean()

mean_salary
# Out:
# salary_year_avg    123286.274072
# dtype: float64

# %%
median_salary = df[['salary_year_avg']].median()

median_salary
# Out:
# salary_year_avg    115000.0
# dtype: float64

# %%
df.salary_hour_avg.notna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_hour_avg, Length: 785741, dtype: bool

# %%
df.salary_hour_avg.isna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 785736    True
# 785737    True
# 785738    True
# 785739    True
# 785740    True
# Name: salary_hour_avg, Length: 785741, dtype: bool

# %%
df.salary_hour_avg
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#           ..
# 785736   NaN
# 785737   NaN
# 785738   NaN
# 785739   NaN
# 785740   NaN
# Name: salary_hour_avg, Length: 785741, dtype: float64

# %%
df.salary_hour_avg.notna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_hour_avg, Length: 785741, dtype: bool

# %%
df.salary_hour_avg.head(5)
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: salary_hour_avg, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.dropna(subset=['salary_hour_avg'], inplace=True)

# %%
df.head()
# Out:
#           job_title_short                                          job_title  \
# 43   Senior Data Engineer  Sr SQL Database Engineer with Data Warehouse /...
# 51   Senior Data Engineer                               Senior Data Engineer
# 253         Data Engineer                                      Data Engineer
# 294          Data Analyst                              Business/Data Analyst
# 340          Data Analyst  23-00059 BI Data Analysts + Media experience -...
#
#      job_location       job_via         job_schedule_type  job_work_from_home  \
# 43           None  via LinkedIn                Contractor               False
# 51       Anywhere  via LinkedIn                Contractor                True
# 253      Anywhere    via Upwork  Contractor and Temp work                True
# 294  Hartford, CT      via Dice                Contractor               False
# 340    California  via LinkedIn                Contractor               False
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10662 entries, 43 to 785492
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        10662 non-null  object
#  1   job_title              10662 non-null  object
#  2   job_location           10586 non-null  object
#  3   job_via                10654 non-null  object
#  4   job_schedule_type      10536 non-null  object
#  5   job_work_from_home     10662 non-null  bool
#  6   search_location        10662 non-null  object
#  7   job_posted_date        10662 non-null  datetime64[ns]
#  8   job_no_degree_mention  10662 non-null  bool
#  9   job_health_insurance   10662 non-null  bool
#  10  job_country            10662 non-null  object
#  11  salary_rate            10662 non-null  object
#  12  salary_year_avg        0 non-null      float64
#  13  salary_hour_avg        10662 non-null  float64
# ...

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('lukebarousse/data_jobs')

# %%
df = dataset['train'].to_pandas()

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.salary_hour_avg.notna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_hour_avg, Length: 785741, dtype: bool

# %%
df.salary_hour_avg.head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: salary_hour_avg, dtype: float64

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df[['salary_hour_avg']].mean()
# Out:
# salary_hour_avg    47.016598
# dtype: float64

# %%
df.salary_hour_avg.min()
# Out:
# 8.0

# %%
df.salary_hour_avg.idxmin()
# Out:
# 88185

# %%
df.iloc[88185]
# Out:
# job_title_short                                             Data Scientist
# job_title                   Data Scientist | W2 Only |Remote then CLT/ ATL
# job_location                                                North Carolina
# job_via                                                           via Dice
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                    New York, United States
# job_posted_date                                        2023-01-20 00:20:23
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                  United States
# salary_rate                                                           hour
# ...

# %%
df.job_country.value_counts()
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
#                    ...
# Guinea                 4
# Lesotho                3
# Mauritania             3
# Bhutan                 3
# Maldives               2
# Name: count, Length: 160, dtype: int64

# %%
job_posting = df.groupby('job_country').size()


job_posting
# Out:
# job_country
# Afghanistan      16
# Albania         119
# Algeria         111
# Angola           11
# Argentina      8736
#                ...
# Venezuela        69
# Vietnam        2414
# Yemen            10
# Zambia          104
# Zimbabwe         81
# Length: 160, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
months = ['January', 'February', 'March', 'April']
postings = [120, 150, 100, 130]
x = months
y = postings
plt.plot(x, y)

# %%
job_titles = ['Data Analyst', 'Data Scientist', 'Data Engineer']
postings = [50, 75, 60]
x = job_titles
y = postings
plt.bar(x, y)
# Out:
# <BarContainer object of 3 artists>

# %%
job_counts = df.job_country.value_counts().head(5)

# %%
bar_graph = plt.bar(job_counts.index, job_counts.values, color='orange')
plt.xlabel('Country')
plt.ylabel('Number of Postings')
plt.title('Number of Jobs per Country')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
job_post = df.groupby('job_title_short')['salary_year_avg'].mean()
job_avg = job_post.sort_values(ascending=True)
plt.barh(job_post.index, job_avg.values)
plt.xlabel('Average Salary')
plt.title('Average Salary by Job Title')
plt.show()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_posted_month'] = df['job_posted_date'].dt.month

# %%
avg_month_salary = df.groupby('job_posted_month')['salary_year_avg'].mean().sort_index().head(6)

plt.plot(avg_month_salary.index, avg_month_salary.values, color= 'red', label='Average Salary')
plt.xlabel('Month')
plt.ylabel('Average Salary')
plt.title('Average Salary by Job Month')
plt.legend()
plt.show()

# %%
top_job_platforms = df.job_via.value_counts().head(5)
top_job_platforms.plot(kind='bar', color='purple')
plt.xlabel('')
plt.show()

# %%
top_job_locations = df.job_location.value_counts().head(5)
top_job_locations.plot(kind='barh', color='green')
plt.xlabel('Count of Jobs')
plt.ylabel('Job Location')
plt.title('Number of Job Postings by Job Location')
plt.show()

# %%
monthly_job_counts = df.groupby(df.job_posted_date.dt.to_period('M'))['job_title'].count().sort_index()
monthly_job_counts.plot(kind='line', color='blue')
plt.xlabel('Month')
plt.ylabel('Number of Job Postings')
plt.title('Trend of Job Postings Over Time')
plt.show()
